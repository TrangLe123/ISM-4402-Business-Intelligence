# %%
import pandas as pd
Location = "C:/Users/Trang Le/OneDrive/Desktop/datasets/axisdata.csv"
df = pd.read_csv(Location)
df.head(100)
# Out:
#        Fname      Lname Gender  Hours Worked SalesTraining  Years Experience  \
# 0       Jada   Walters       F            39             N                 3
# 1     Nicole  Henderson      F            46             N                 3
# 2      Tanya      Moore      F            42             Y                 4
# 3    Ronelle    Jackson      F            38             Y                 5
# 4       Brad      Sears      M            33             N                 4
# ..       ...        ...    ...           ...           ...               ...
# 95  Francine    Kennedy      F            39             Y                 4
# 96     Roger       Sapp      M            41             Y                 1
# 97      Lisa     Looner      F            48             Y                 2
# 98    Nicole       Sapp      F            38             Y                 2
# 99       Tom      Adams      M            44             N                 2
#
#     Cars Sold
# 0           2
# ...

# %%
#1 Average Cars Sold per month
df['Cars Sold'].mean()
# Out:
# 3.9229229229229228

# %%
#2 Max Cars Sold per month
df['Cars Sold'].max()
# Out:
# 7

# %%
#3 Min Cars Sold per month
df['Cars Sold'].min()
# Out:
# 1

# %%
#4 Average Cars Sold per month by gender
pd.pivot_table(df, values = ['Cars Sold'], index = ['Gender'], aggfunc = 'mean')
# Out:
#         Cars Sold
# Gender
# F        3.760736
# M        4.078431

# %%
#5 Average Hours Worked by people selling more than 3 cars per month
df1 = df.loc[df['Cars Sold'] > 3]
pd.pivot_table(df1, index = ['Fname'], values = ['Hours Worked'], aggfunc = 'mean')
# Out:
#           Hours Worked
# Fname
# Aaron        34.600000
# Adam         32.666667
# August       34.500000
# Betty        35.428571
# Brad         34.800000
# Carla        33.850000
# Charles      33.850000
# David        30.000000
# Denise       33.117647
# Evelyn       29.750000
# Francine     32.916667
# Frank        34.111111
# Harold       34.125000
# Jack         36.416667
# Jackie       34.571429
# Jada         34.285714
# John         33.538462
# Karen        36.312500
# Larry        32.933333
# Lisa         40.363636
# Martin       33.950000
# Mary         34.250000
# Mike         35.846154
# Nicole       34.300000
# Oliver       32.200000
# Onika        34.600000
# Paula        36.000000
# Peter        36.909091
# Roger        34.294118
# Ronelle      35.727273
# Sam          36.030303
# Samantha     35.533333
# Tanya        34.416667
# Tom          36.904762
# Veronica     35.600000
# Victor       36.263158
# Victoria     34.615385
# Walter       33.666667
# ...

# %%
#6 Average Years of Experience
df['Years Experience'].mean()
# Out:
# 3.026026026026026

# %%
#7 Average Years of Experience for people selling more than 3 cars per month
df2 = df.loc[df['Cars Sold'] > 3]
pd.pivot_table(df2, index = ['Fname'], values = ['Years Experience'], aggfunc = 'mean')
# Out:
#           Years Experience
# Fname
# Aaron             2.866667
# Adam              2.733333
# August            3.666667
# Betty             2.714286
# Brad              2.900000
# Carla             2.400000
# Charles           2.850000
# David             2.166667
# Denise            3.058824
# Evelyn            3.125000
# Francine          2.750000
# Frank             3.166667
# Harold            2.375000
# Jack              3.083333
# Jackie            2.857143
# Jada              3.500000
# John              2.846154
# Karen             2.875000
# Larry             3.066667
# Lisa              3.181818
# Martin            3.150000
# Mary              3.500000
# Mike              2.769231
# Nicole            3.000000
# Oliver            3.300000
# Onika             2.900000
# Paula             3.576923
# Peter             3.181818
# Roger             3.058824
# Ronelle           3.000000
# Sam               3.454545
# Samantha          2.800000
# Tanya             2.500000
# ...

# %%
#8 Average Cars Sold per month sorted by whether they have had sales training.
df3 = df.loc[df['SalesTraining'] == 'Y']
pd.pivot_table(df3, index = ['Fname', 'Lname'], values = ['Cars Sold'], aggfunc = 'mean')
# Out:
#                 Cars Sold
# Fname Lname
# Aaron Adams           6.0
#       Ettienne        6.0
#       Gerardo         4.0
#       Harrison        4.0
#       Isaacson        5.0
# ...                   ...
# india Martins         2.0
#       Rogers          6.0
#       Rose            4.0
#       Vaughn          3.0
#       Withers         5.0
#
# [467 rows x 1 columns]

# %%
#Question: What do you think is the best indicator of whether someone is a good salesperson?
# From my basic knowledge of business, the best indicator of if someone is a good salesperson 
# is looking at the number of cars he/she can sell per month. I used filter in the excel file
# to see that who are the good salespersons and also see that all those people had sales training.
# The number of years experience and hours worked are not problems.

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
df = pd.read_csv("C:/Users/Trang Le/OneDrive/Desktop/datasets/axisdata.csv")
df.head()
# Out:
#      Fname      Lname Gender  Hours Worked SalesTraining  Years Experience  \
# 0     Jada   Walters       F            39             N                 3
# 1   Nicole  Henderson      F            46             N                 3
# 2    Tanya      Moore      F            42             Y                 4
# 3  Ronelle    Jackson      F            38             Y                 5
# 4     Brad      Sears      M            33             N                 4
#
#    Cars Sold
# 0          2
# 1          6
# 2          6
# 3          3
# 4          2

# %%
df.hist(column = "Cars Sold", by = "Gender")
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027CDA999C10>,
# ...
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
Location = "C:/Users/Trang Le/OneDrive/Desktop/datasets/axisdata.csv"
df = pd.read_csv(Location)
df.plot.scatter(x = 'Cars Sold', y = 'Hours Worked')
plt.xlabel('Cars Sold')
plt.ylabel('Hours Worked')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
Location = "C:/Users/Trang Le/OneDrive/Desktop/datasets/axisdata.csv"
df = pd.read_csv(Location)
df.hist(column = 'Hours Worked')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027CDBC9BB20>]],
#       dtype=object)
